# %%
import pandas as pd
import requests

# %%
url = 'https://servicodados.ibge.gov.br/api/v2/censos/nomes/matheus/'

params = {'sexo': 'M',
          'localidade': 32}

response = requests.request("GET", url = url, params = params)

# %%
# Confere o status
response.status_code
# Out:
# 200

# %%
# Seleciona o primeiro índice da lista
data_json = response.json()[0]['res']

# %%
# Cria o dataframe
matheus_df = pd.DataFrame(data_json)
display(matheus_df)
# Out:
#        periodo  frequencia
# 0  [1950,1960[          20
# 1  [1960,1970[          23
# 2  [1970,1980[          53
# 3  [1980,1990[         210
# 4  [1990,2000[        2437
# 5  [2000,2010[        3375

# %%
import seaborn as sns
from matplotlib import pyplot as plt

sns.barplot(data = matheus_df, x = 'periodo', y = 'frequencia')
plt.xticks(rotation = 55);
